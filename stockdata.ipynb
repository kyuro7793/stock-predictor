# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\andyr\\Documents\\file\\side\\projects\\stock'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'forbes2000',
#  'nasdaq',
#  'nyse',
#  'sp500',
#  'stockdata.ipynb']

# %%
path="C:\\Users\\andyr\\Documents\\file\\side\\projects\\stock\\sp500\\csv"

# %%
os.chdir(path)

# %%
data=pd.read_csv(os.path.join(path,"AAPL.csv"))

# %%
data.head()
# Out:
#          Date       Low      Open     Volume      High     Close  \
# 0  12-12-1980  0.128348  0.128348  469033600  0.128906  0.128348
# 1  15-12-1980  0.121652  0.122210  175884800  0.122210  0.121652
# 2  16-12-1980  0.112723  0.113281  105728000  0.113281  0.112723
# 3  17-12-1980  0.115513  0.115513   86441600  0.116071  0.115513
# 4  18-12-1980  0.118862  0.118862   73449600  0.119420  0.118862
#
#    Adjusted Close
# 0        0.100326
# 1        0.095092
# 2        0.088112
# 3        0.090293
# 4        0.092911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10401 entries, 0 to 10400
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10401 non-null  object
#  1   Low             10401 non-null  float64
#  2   Open            10401 non-null  float64
#  3   Volume          10401 non-null  int64
#  4   High            10401 non-null  float64
#  5   Close           10401 non-null  float64
#  6   Adjusted Close  10401 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 568.9+ KB

# %%
# datetime

data["Date"]
# Out:
# 0        12-12-1980
# 1        15-12-1980
# 2        16-12-1980
# 3        17-12-1980
# 4        18-12-1980
#             ...
# 10396    08-03-2022
# 10397    09-03-2022
# 10398    10-03-2022
# 10399    11-03-2022
# 10400    14-03-2022
# Name: Date, Length: 10401, dtype: object

# %%
data["Date"]=pd.to_datetime(data["Date"],format="%d-%m-%Y")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10401 entries, 0 to 10400
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10401 non-null  datetime64[ns]
#  1   Low             10401 non-null  float64
#  2   Open            10401 non-null  float64
#  3   Volume          10401 non-null  int64
#  4   High            10401 non-null  float64
#  5   Close           10401 non-null  float64
#  6   Adjusted Close  10401 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 568.9 KB

# %%
# Datetime advantages
data.Date.dt.day
# Out:
# 0        12
# 1        15
# 2        16
# 3        17
# 4        18
#          ..
# 10396     8
# 10397     9
# 10398    10
# 10399    11
# 10400    14
# Name: Date, Length: 10401, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.describe()
# Out:
#                 Low          Open        Volume          High         Close  \
# count  10401.000000  10401.000000  1.040100e+04  10401.000000  10401.000000
# mean      13.696066     13.846126  3.323546e+08     13.995533     13.850906
# std       29.565826     29.899972  3.394051e+08     30.235982     29.912311
# min        0.049107      0.049665  0.000000e+00      0.049665      0.049107
# 25%        0.274554      0.281250  1.248688e+08      0.287946      0.281250
# 50%        0.459821      0.468750  2.204160e+08      0.477679      0.467634
# 75%       13.982143     14.178571  4.129160e+08     14.295357     14.158929
# max      179.119995    182.630005  7.421641e+09    182.940002    182.009995
#
#        Adjusted Close
# count    10401.000000
# mean        13.234013
# std         29.626464
# min          0.038385
# 25%          0.234675
# 50%          0.385950
# 75%         12.133098
# max        181.778397

# %%
data.Date.max()
# Out:
# Timestamp('2022-03-14 00:00:00')

# %%
data.Date.min()
# Out:
# Timestamp('1980-12-12 00:00:00')

# %%
data_2021=data.loc[data.Date.dt.year==2021]

# %%
data_2021
# Out:
#             Date         Low        Open     Volume        High       Close  \
# 10100 2021-01-04  126.760002  133.520004  143301900  133.610001  129.410004
# 10101 2021-01-05  128.429993  128.889999   97664900  131.740005  131.009995
# 10102 2021-01-06  126.379997  127.720001  155088000  131.050003  126.599998
# 10103 2021-01-07  127.860001  128.360001  109578200  131.630005  130.919998
# 10104 2021-01-08  130.229996  132.429993  105158200  132.630005  132.050003
# ...          ...         ...         ...        ...         ...         ...
# 10347 2021-12-27  177.070007  177.089996   74919600  180.419998  180.330002
# 10348 2021-12-28  178.529999  180.160004   79144300  181.330002  179.289993
# 10349 2021-12-29  178.139999  179.330002   62348900  180.630005  179.380005
# 10350 2021-12-30  178.089996  179.470001   59773000  180.570007  178.199997
# 10351 2021-12-31  177.259995  178.089996   64062300  179.229996  177.570007
#
#        Adjusted Close
# 10100      128.453461
# ...

# %%
plt.bar(data_2021.Date,data_2021.Volume)
# Out:
# <BarContainer object of 252 artists>

# %%
data_2021["month"]=data_2021.Date.dt.month
# Out:
# C:\Users\andyr\AppData\Local\Temp/ipykernel_21960/582818118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021["month"]=data_2021.Date.dt.month

# %%
mom=data_2021.groupby("month").agg({"Volume":"mean"})

# %%
plt.plot(mom.index,mom["Volume"])

# %%
data_2020=data.loc[data.Date.dt.year==2020]

# %%
data_2020
# Out:
#             Date         Low        Open     Volume        High       Close  \
# 9847  2020-01-02   73.797501   74.059998  135480400   75.150002   75.087502
# 9848  2020-01-03   74.125000   74.287498  146322800   75.144997   74.357498
# 9849  2020-01-06   73.187500   73.447502  118387200   74.989998   74.949997
# 9850  2020-01-07   74.370003   74.959999  108872000   75.224998   74.597504
# 9851  2020-01-08   74.290001   74.290001  132079200   76.110001   75.797501
# ...          ...         ...         ...        ...         ...         ...
# 10095 2020-12-24  131.100006  131.320007   54930100  133.460007  131.970001
# 10096 2020-12-28  133.509995  133.990005  124486200  137.339996  136.690002
# 10097 2020-12-29  134.339996  138.050003  121047300  138.789993  134.869995
# 10098 2020-12-30  133.399994  135.580002   96452100  135.990005  133.720001
# 10099 2020-12-31  131.720001  134.080002   99116600  134.740005  132.690002
#
#        Adjusted Close
# 9847        73.894325
# ...

# %%
data_2020.describe()
# Out:
#               Low        Open        Volume        High       Close  \
# count  253.000000  253.000000  2.530000e+02  253.000000  253.000000
# mean    93.912796   95.267668  1.575646e+08   96.661769   95.347075
# std     21.579913   22.011907  6.983072e+07   22.094637   21.809814
# min     53.152500   57.020000  4.669130e+07   57.125000   56.092499
# 25%     76.220001   77.025002  1.108432e+08   78.167503   77.385002
# 50%     90.910004   91.279999  1.380234e+08   92.970001   91.632500
# 75%    114.129997  115.982498  1.875728e+08  117.279999  115.750000
# max    134.339996  138.050003  4.265100e+08  138.789993  136.690002
#
#        Adjusted Close
# count      253.000000
# mean        94.341267
# std         21.791903
# min         55.332172
# 25%         76.177460
# 50%         90.635109
# 75%        114.696533
# max        135.679626

# %%
data_2020.max()
# Out:
# Date              2020-12-31 00:00:00
# Low                        134.339996
# Open                       138.050003
# Volume                      426510000
# High                       138.789993
# Close                      136.690002
# Adjusted Close             135.679626
# dtype: object

# %%
data_2020.min()
# Out:
# Date              2020-01-02 00:00:00
# Low                           53.1525
# Open                            57.02
# Volume                       46691300
# High                           57.125
# Close                       56.092499
# Adjusted Close              55.332172
# dtype: object

# %%
data_2020["month"] = data_2020.Date.dt.month
# Out:
# C:\Users\andyr\AppData\Local\Temp/ipykernel_21960/3067379757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020["month"] = data_2020.Date.dt.month

# %%
data_2020["month"]
# Out:
# 9847      1
# 9848      1
# 9849      1
# 9850      1
# 9851      1
#          ..
# 10095    12
# 10096    12
# 10097    12
# 10098    12
# 10099    12
# Name: month, Length: 253, dtype: int64

# %%
moms = data_2020.groupby("month").agg({'Volume':'mean'})

# %%
plt.plot(moms.index,moms["Volume"])

# %%
data["year"]=data.Date.dt.year

# %%
yoy=data.groupby("year").agg({"Volume":"mean"})

# %%
yoy
# Out:
#             Volume
# year
# 1980  1.034501e+08
# 1981  3.239899e+07
# 1982  8.444667e+07
# 1983  1.759408e+08
# 1984  1.659250e+08
# 1985  1.805249e+08
# 1986  2.107637e+08
# 1987  2.362502e+08
# 1988  1.632134e+08
# 1989  2.020072e+08
# 1990  1.755017e+08
# 1991  2.266706e+08
# 1992  1.619603e+08
# 1993  2.231341e+08
# 1994  2.268091e+08
# 1995  2.947085e+08
# 1996  2.094261e+08
# 1997  2.844402e+08
# 1998  4.571198e+08
# 1999  5.440584e+08
# 2000  4.773873e+08
# 2001  3.816847e+08
# 2002  3.056108e+08
# 2003  2.826597e+08
# 2004  4.833400e+08
# 2005  7.238134e+08
# 2006  8.593584e+08
# 2007  9.840478e+08
# 2008  1.130360e+09
# 2009  5.684670e+08
# 2010  5.993053e+08
# 2011  4.922990e+08
# 2012  5.278568e+08
# 2013  4.064348e+08
# 2014  2.526109e+08
# 2015  2.073976e+08
# 2016  1.536901e+08
# 2017  1.085383e+08
# 2018  1.360803e+08
# 2019  1.121228e+08
# 2020  1.575646e+08
# 2021  9.051701e+07
# 2022  9.453624e+07

# %%
plt.figure(figsize=(10,10))
plt.plot(yoy.index,yoy.Volume)
plt.xlim(2000,2010)
# Out:
# (2000.0, 2010.0)

# %%
plt.boxplot(data.Low)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21e52497190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21e524978b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21e526d6dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21e52497fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21e524a33a0>],
#  'means': []}

# %%
for colname in data.drop("Date",axis=1).columns:
    
    plt.boxplot(data[colname])
    plt.title(colname)
    plt.show()

# %%
# sample-mean/std

mean=data.Volume.mean()
sd=data.Volume.std()

# %%
outliers = []
for index,value in enumerate(data.Volume):
    z=(value-mean)/sd
    if abs(z) > 3:
        outliers.append(index)

# %%
outliers
# Out:
# [703,
#  2054,
#  2612,
#  2624,
#  3183,
#  4061,
#  4209,
#  4210,
#  4211,
#  4212,
#  4276,
#  4314,
#  4383,
#  4446,
#  4464,
#  4509,
#  4565,
#  4567,
#  4572,
#  4634,
#  4642,
#  4645,
#  4646,
#  4692,
#  4697,
#  4733,
#  4744,
#  4749,
#  4761,
#  4828,
#  5004,
#  5005,
#  5006,
#  5007,
#  5018,
#  5051,
#  5142,
#  5432,
#  5637,
#  5652,
#  5653,
#  5863,
#  5891,
#  5953,
#  6017,
#  6044,
#  6046,
#  6048,
#  6076,
#  6077,
#  6078,
#  6079,
#  6080,
#  6081,
#  6091,
#  6102,
#  6103,
#  6104,
#  6108,
#  6113,
#  6141,
#  6142,
#  6143,
#  6161,
#  6205,
#  6268,
#  6269,
#  6274,
#  6312,
#  6329,
#  6330,
#  6335,
#  6342,
#  6347,
#  6348,
#  6351,
#  6379,
#  6382,
#  6383,
#  6384,
#  6388,
#  6389,
#  6390,
#  6398,
#  6432,
#  6460,
#  6461,
#  6472,
#  6498,
#  6525,
#  6572,
#  6579,
#  6580,
#  6581,
#  6584,
#  6585,
#  6586,
#  6587,
#  6614,
#  6653,
#  6676,
#  6682,
#  6684,
#  6685,
#  6686,
#  6701,
#  6714,
#  6715,
#  6716,
#  6719,
#  6720,
# ...

# %%
data=data.drop(outliers,axis=0)

# %%
IQR=data.Volume.quantile(0.75)-data.Volume.quantile(0.25)

# %%
IQR
# Out:
# 275106575.0

# %%
upper_limit=data.Volume.quantile(0.75)+IQR*1.5

# %%
upper_limit
# Out:
# 811187362.5

# %%
removing_indexes=data.loc[data.Volume>upper_limit].index

# %%
data_free_outlier=data.drop(removing_indexes,axis=0)

# %%
outliers = []

# %%
mean=data_free_outlier.Low.mean()

# %%
sd=data_free_outlier.Low.std()

# %%
for index,value in enumerate(data_free_outlier.Low):
    z=(value-mean)/sd
    if abs(z) > 3 :
        outliers.append(index)

# %%
len(outliers)
# Out:
# 404

# %%
data_free_outlier.shape
# Out:
# (9566, 8)

# %%
data_free_outlier = data_free_outlier.drop(outliers,axis=0)

# %%
plt.boxplot(data_free_outlier.Low)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21e52390bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21e523c3340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21e501c53d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21e523c3b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21e5289e280>],
#  'means': []}

# %%
IQR=data.Low.quantile(0.75)-data.Low.quantile(0.25)

# %%
IQR
# Out:
# 14.352500177919865

# %%
upper_limit=data.Low.quantile(0.75)+IQR*1.5

# %%
upper_limit
# Out:
# 36.150982704013586

# %%
removing_indexes=data.loc[data.Low>upper_limit].index

# %%
data_free_outlier=data.drop(removing_indexes,axis=0)

# %%
data_free_outlier.shape
# Out:
# (8993, 8)

# %%
plt.boxplot(data_free_outlier.Low)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21e5291c040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21e5291c760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21e5290dc70>],
#  'medians': [<matplotlib.lines.Line2D at 0x21e5291ce80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21e52928250>],
#  'means': []}

# %%
plt.scatter(data_free_outlier.Volume,data_free_outlier.Low)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# %%
dbs=DBSCAN(eps=500000)

# %%
data_free_outlier=data_free_outlier.drop("year",axis=1)

# %%
data_free_outlier=data_free_outlier.drop("Date",axis=1)

# %%
dbs.fit(data_free_outlier)
# Out:
# DBSCAN(eps=500000)

# %%
data_free_outlier["clus"]=dbs.labels_

# %%
reove_index=data_free_outlier.loc[data_free_outlier.clus==-1].index

# %%
data_free_outlier=data_free_outlier.drop(reove_index,axis=0)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nn=NearestNeighbors(n_neighbors=2)

# %%
nbrs=nn.fit(data_free_outlier)

# %%
dist,indices=nbrs.kneighbors(data_free_outlier)

# %%
dist
# Out:
# array([[0.00000000e+00, 5.60001437e+03],
#        [0.00000000e+00, 2.24000000e+04],
#        [0.00000000e+00, 1.00456178e-02],
#        ...,
#        [0.00000000e+00, 5.68000551e+04],
#        [0.00000000e+00, 9.88000004e+04],
#        [0.00000000e+00, 1.00003254e+04]])

# %%
dist_sort=np.sort(dist,axis=0)

# %%
dist_sort[:,1]
# Out:
# array([3.59461134e-03, 3.59461134e-03, 3.88378444e-03, ...,
#        4.87200000e+05, 4.90000000e+05, 4.92800000e+05])

# %%
plt.plot(dist_sort[:,1])

# %%
data_free_outlier=data_free_outlier.drop("clus",axis=1)

# %%
data_free_outlier.corr()
# Out:
#                      Low      Open    Volume      High     Close  \
# Low             1.000000  0.999955  0.057965  0.999952  0.999964
# Open            0.999955  1.000000  0.059347  0.999967  0.999913
# Volume          0.057965  0.059347  1.000000  0.060359  0.059125
# High            0.999952  0.999967  0.060359  1.000000  0.999960
# Close           0.999964  0.999913  0.059125  0.999960  1.000000
# Adjusted Close  0.999353  0.999260  0.045230  0.999294  0.999367
#
#                 Adjusted Close
# Low                   0.999353
# Open                  0.999260
# Volume                0.045230
# High                  0.999294
# Close                 0.999367
# Adjusted Close        1.000000

# %%
from scipy.stats import pearsonr

# %%
X=data_free_outlier.drop("Adjusted Close",axis=1)

# %%
y=data_free_outlier["Adjusted Close"]

# %%
dict_c={}
for feat1 in X.columns:
    for feat2 in X.columns:
        if feat1==feat2:
            continue
        else:
            if f"{feat1},{feat2}" in dict_c.keys() or  f"{feat2},{feat1}" in dict_c.keys():
                continue
            corr,p=pearsonr(X[feat1],X[feat2])
            dict_c[f"{feat1},{feat2}"]=corr
            if corr>0.95:
                corr1,p=pearsonr(X[feat1],y)
                corr2,p=pearsonr(X[feat2],y)
                if corr1>corr2:
                    keep_column.append(feat1)
                else:
                    keep_column.append(feat2)
                    
            else:
                keep_column.append([feat1,feat2])

# %%
dict_c
# Out:
# {'Low,Open': 0.9999545553329694,
#  'Low,Volume': 0.05796528236081462,
#  'Low,High': 0.9999520133873934,
#  'Low,Close': 0.9999640981227323,
#  'Open,Volume': 0.0593466817743818,
#  'Open,High': 0.9999665697983231,
#  'Open,Close': 0.9999125100768949,
#  'Volume,High': 0.06035898188174995,
#  'Volume,Close': 0.059124804655034086,
#  'High,Close': 0.9999596012588751}

# %%
for key in dict_c.keys():
    if dict_c[key]>0.95:
        x,z=key.split(",")
        
        corr1,p=pearsonr(X[x],y)
        corr2,p=pearsonr(X[z],y)
        
        if corr1>corr2:
            print(x)
        else:
            print(z)
    else:
        x,z=key.split(",")
        print("noncollinear")
        print(x,z)
# Out:
# Low
# noncollinear
# Low Volume
# Low
# Close
# noncollinear
# Open Volume
# High
# Close
# noncollinear
# Volume High
# noncollinear
# Volume Close
# Close

# %%
# variance inflation test

#1/1-r2

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_df=pd.DataFrame()

# %%
vif_df["features"]=X.columns

# %%
vif_l=[]
for i in range(len(X.columns)):
    vif=variance_inflation_factor(X.values,i)
    vif_l.append(vif)

# %%
vif_df["vif"]=vif_l

# %%
vif_df
# Out:
#   features           vif
# 0      Low  42649.769431
# 1     Open  40411.546661
# 2   Volume      1.284956
# 3     High  53164.849447
# 4    Close  41398.421362

# %%
X=data_free_outlier["Adjusted Close"]

# %%
# split data

from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
model=LinearRegression()

# %%
model.fit(np.array(x_train).reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
model.score(np.array(x_train).reshape(-1,1),y_train)
# Out:
# 1.0

# %%
model.score(np.array(x_test).reshape(-1,1),y_test)
# Out:
# 1.0

# %%
model.coef_
# Out:
# array([1.])

# %%
import matplotlib.pyplot as plt

# %%
imp={}

for feat,impo in zip(X.columns,model.coef_):
    imp[feat]=impo

# %%
imp_df=pd.DataFrame(imp,index=range(0,1))

# %%
imp_df=pd.melt(imp_df)

# %%
imp_df
# Out:
#         Low      Open        Volume     High     Close
# 0  0.246717 -0.149339 -6.089969e-10 -0.14795  0.963775

# %%
plt.bar(imp_df.variable,imp_df.value)
# Out:
# <BarContainer object of 5 artists>

# %%
X=data_free_outlier.drop(["Close","Adjusted Close"],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.9989008712718226

# %%
model.score(x_test,y_test)
# Out:
# 0.9989225314954489
